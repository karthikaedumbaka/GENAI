# %%
import os
from langchain_openai import ChatOpenAI
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.output_parsers import PydanticOutputParser
from pydantic import BaseModel ,Field
from langchain.schema.runnable import RunnableParallel,RunnableBranch,RunnableLambda
from typing import Literal
load_dotenv()
# Out:
# True

# %%
# Model
model = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",
    google_api_key=os.environ["GEMINI_API_KEY"]
)

# %%
from langchain_community.document_loaders import TextLoader

# %%
loader = TextLoader("poem_India.txt",encoding="utf-8")

# %%
docs = loader.load()

# %%
prompt = PromptTemplate(
    template="Write a summary for thr following poem \n - {poem}",
    input_variables=['poem']
)

# %%
parser = StrOutputParser()

# %%
chain = prompt | model |parser

# %%
chain.invoke(docs[0])
# Out:
# "This poem is a celebration of India's vast and vibrant identity. It highlights the country's diverse landscapes, from the Himalayas to the deserts and oceans, and its rich cultural tapestry woven from multiple languages, religions, and traditions. The poem acknowledges India's historical depth, referencing ancient wisdom, royal legacies, and significant monuments. It also touches upon the struggle for independence and the nation's subsequent rebirth. Ultimately, the poem portrays India as a resilient and enduring land, a mosaic of joy and sorrow, constantly evolving while remaining deeply connected to its roots, and leaving a lasting story on the world."
