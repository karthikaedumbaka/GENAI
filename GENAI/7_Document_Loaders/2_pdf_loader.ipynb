# %%
import os
from langchain_openai import ChatOpenAI
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.output_parsers import PydanticOutputParser
from pydantic import BaseModel ,Field
from langchain.schema.runnable import RunnableParallel,RunnableBranch,RunnableLambda
from typing import Literal
load_dotenv()
# Out:
# True

# %%
from langchain_community.document_loaders import  PyPDFLoader

# %%
load = PyPDFLoader("scikit-learn-docs.pdf")

# %%
loader = load.load()

# %%
print(loader[0])
# Out:
# page_content='scikit-learn user guide
# Release 0.22.2
# scikit-learn developers
# Mar 04, 2020' metadata={'producer': 'pdfTeX-1.40.17', 'creator': 'LaTeX with hyperref package', 'creationdate': '2020-03-04T17:32:40+00:00', 'author': 'scikit-learn developers', 'title': 'scikit-learn user guide', 'subject': '', 'keywords': '', 'moddate': '2020-03-04T17:32:40+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.17 (TeX Live 2016/Debian) kpathsea version 6.2.2', 'source': 'scikit-learn-docs.pdf', 'total_pages': 2673, 'page': 0, 'page_label': '1'}
