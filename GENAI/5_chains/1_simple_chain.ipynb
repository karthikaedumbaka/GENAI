# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
load_dotenv()
# Out:
# True

# %%
prompt=PromptTemplate(
    template='Genrate 1 interesting fact about {topic}',
    input_variables=['topic']
)

# %%
model =ChatOpenAI(model="gpt-4o-mini")

# %%
parser = StrOutputParser()
chain = prompt | model | parser  # this called chain

# %%
chain.invoke({'topic':'GENAI'})
# Out:
# "One interesting fact about Generative AI (GenAI) is that it can create entirely new content, such as images, music, and text, by learning patterns from vast amounts of existing data. For example, models like OpenAI's DALL-E can generate unique images from textual descriptions, enabling users to visualize concepts and ideas that may not have previously existed. This capability not only enhances creativity and innovation but also has implications in fields like art, design, and even storytelling, pushing the boundaries of human-machine collaboration."

# %%
print(chain.get_graph())
# Out:
# Graph(nodes={'a249c1a90d654923882b563c14a860b5': Node(id='a249c1a90d654923882b563c14a860b5', name='PromptInput', data=<class 'langchain_core.utils.pydantic.PromptInput'>, metadata=None), 'cfffa4e8a494440d86d5005d0958914c': Node(id='cfffa4e8a494440d86d5005d0958914c', name='PromptTemplate', data=PromptTemplate(input_variables=['topic'], input_types={}, partial_variables={}, template='Genrate 1 interesting fact about {topic}'), metadata=None), 'a88f63c888e149fa9d76914d7b550808': Node(id='a88f63c888e149fa9d76914d7b550808', name='ChatOpenAI', data=ChatOpenAI(client=<openai.resources.chat.completions.completions.Completions object at 0x000002473AEB31D0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000002473AEB2150>, root_client=<openai.OpenAI object at 0x000002473AEA2300>, root_async_client=<openai.AsyncOpenAI object at 0x000002473AEB1130>, model_name='gpt-4o-mini', model_kwargs={}, openai_api_key=SecretStr('**********')), metadata=None), 'ca826c86805141eaaadc2e6ef42a0ea1': Node(id='ca826c86805141eaaadc2e6ef42a0ea1', name='StrOutputParser', data=StrOutputParser(), metadata=None), 'e4e5a037a2ae4e4794ad94fbed65cd3a': Node(id='e4e5a037a2ae4e4794ad94fbed65cd3a', name='StrOutputParserOutput', data=<class 'langchain_core.output_parsers.string.StrOutputParserOutput'>, metadata=None)}, edges=[Edge(source='a249c1a90d654923882b563c14a860b5', target='cfffa4e8a494440d86d5005d0958914c', data=None, conditional=False), Edge(source='cfffa4e8a494440d86d5005d0958914c', target='a88f63c888e149fa9d76914d7b550808', data=None, conditional=False), Edge(source='ca826c86805141eaaadc2e6ef42a0ea1', target='e4e5a037a2ae4e4794ad94fbed65cd3a', data=None, conditional=False), Edge(source='a88f63c888e149fa9d76914d7b550808', target='ca826c86805141eaaadc2e6ef42a0ea1', data=None, conditional=False)])
