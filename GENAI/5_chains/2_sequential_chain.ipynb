# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
load_dotenv()
# Out:
# True

# %%
prompt1=PromptTemplate(
    template='Generate a detaild report on {topic} in 5 lines',
    input_variables=['t0pic']
)
prompt2=PromptTemplate(
    template='Generate a 3 topics from the following text \n {text}',
    input_variables=['text']
    
)

# %%
model=ChatOpenAI(model="gpt-4o-mini")
parser = StrOutputParser()

# %%
chain = prompt1 | model | parser | prompt2 | model | parser

# %%
result = chain.invoke({'topic' : "Anout GenAI"})

# %%
print(result)
# Out:
# 1. **Applications of Generative AI Across Industries**: Exploring how Anout GenAI utilizes advanced AI techniques for content creation and innovation in sectors such as entertainment, marketing, and education.
#
# 2. **Ethical Considerations in Generative AI**: Addressing the importance of ethical AI use, including transparency and bias mitigation in the development and deployment of AI-generated content.
#
# 3. **Future Trends in Generative AI Development**: Discussing the ongoing evolution of Anout GenAI's models aimed at enhancing creativity, user experience, and responsible AI practices.

# %%
chain.get_graph().print_ascii()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\karth\OneDrive\Desktop\LEARN_GENAI\GENAI\venv\Lib\site-packages\langchain_core\runnables\graph_ascii.py:178, in _build_sugiyama_layout(vertices, edges)
#     177 try:
# --> 178     from grandalf.graphs import Edge, Graph, Vertex  # type: ignore[import-untyped]
#     179     from grandalf.layouts import SugiyamaLayout  # type: ignore[import-untyped]
#
# ModuleNotFoundError: No module named 'grandalf'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 chain.get_graph().print_ascii()
#
# File c:\Users\karth\OneDrive\Desktop\LEARN_GENAI\GENAI\venv\Lib\site-packages\langchain_core\runnables\graph.py:526, in Graph.print_ascii(self)
#     524 def print_ascii(self) -> None:
#     525     """Print the graph as an ASCII art string."""
# --> 526     print(self.draw_ascii())
#
# File c:\Users\karth\OneDrive\Desktop\LEARN_GENAI\GENAI\venv\Lib\site-packages\langchain_core\runnables\graph.py:519, in Graph.draw_ascii(self)
#     516 """Draw the graph as an ASCII art string."""
#     517 from langchain_core.runnables.graph_ascii import draw_ascii
# --> 519 return draw_ascii(
#     520     {node.id: node.name for node in self.nodes.values()},
#     521     self.edges,
#     522 )
#
# File c:\Users\karth\OneDrive\Desktop\LEARN_GENAI\GENAI\venv\Lib\site-packages\langchain_core\runnables\graph_ascii.py:273, in draw_ascii(vertices, edges)
#     270 xlist: list[float] = []
#     271 ylist: list[float] = []
# --> 273 sug = _build_sugiyama_layout(vertices, edges)
#     275 for vertex in sug.g.sV:
#     276     # NOTE: moving boxes w/2 to the left
#     277     xlist.extend(
#     278         (
#     279             vertex.view.xy[0] - vertex.view.w / 2.0,
#     280             vertex.view.xy[0] + vertex.view.w / 2.0,
#     281         )
#     282     )
#
# File c:\Users\karth\OneDrive\Desktop\LEARN_GENAI\GENAI\venv\Lib\site-packages\langchain_core\runnables\graph_ascii.py:183, in _build_sugiyama_layout(vertices, edges)
#     181 except ImportError as exc:
#     182     msg = "Install grandalf to draw graphs: `pip install grandalf`."
# --> 183     raise ImportError(msg) from exc
#     185 #
#     186 # Just a reminder about naming conventions:
#     187 # +------------X
#    (...)    192 # Y
#     193 #
#     195 vertices_ = {id_: Vertex(f" {data} ") for id_, data in vertices.items()}
#
# ImportError: Install grandalf to draw graphs: `pip install grandalf`.
